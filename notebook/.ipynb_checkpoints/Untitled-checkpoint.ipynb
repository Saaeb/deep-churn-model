# %%
#importing required libraries
from torch import nn
import pandas as pd
import matplotlib as plt

# %%
df=pd.read_csv("../input/data.csv")

# %%
df.head()
# Out:
#    year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 0  2015       100198  409-8743  Female   36                     62
# 1  2015       100643  340-5930  Female   39                    149
# 2  2015       100756  372-3750  Female   65                    126
# 3  2015       101595  331-4902  Female   24                    131
# 4  2015       101653  351-8398  Female   40                    191
#
#   multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# 0           no              no               148.35                12.2
# 1           no              no               294.45                 7.7
# 2           no              no                87.30                11.9
# 3           no             yes               321.30                 9.5
# 4           no              no               243.00                10.9
#
#    maximum_daily_mins  weekly_max_night_mins  videos_watched  \
# 0               16.81                     82               1
# 1               33.37                     87               3
# 2                9.89                     91               1
# 3               36.41                    102               4
# 4               27.54                     83               7
#
#    maximum_days_inactive  customer_support_calls  churn
# 0                    4.0                       1    0.0
# 1                    3.0                       2    0.0
# 2                    4.0                       5    1.0
# 3                    3.0                       3    0.0
# 4                    3.0                       1    0.0

# %%
#dropping columns
data = df.drop(["customer_id", "phone_no", "year"], axis=1)

# %%
data.tail()
# Out:
#       gender  age  no_of_days_subscribed multi_screen mail_subscribed  \
# 1995  Female   54                     75           no             yes
# 1996    Male   45                    127           no              no
# 1997     NaN   53                     94           no              no
# 1998    Male   40                     94           no              no
# 1999    Male   37                     73           no              no
#
#       weekly_mins_watched  minimum_daily_mins  maximum_daily_mins  \
# 1995               182.25                11.3               20.66
# 1996               273.45                 9.3               30.99
# 1997               128.85                15.6               14.60
# 1998               178.05                10.4               20.18
# 1999               326.70                10.3               37.03
#
#       weekly_max_night_mins  videos_watched  maximum_days_inactive  \
# 1995                     97               5                    4.0
# 1996                    116               3                    3.0
# 1997                    110              16                    5.0
# 1998                    100               6                    NaN
# 1999                     89               6                    3.0
#
#       customer_support_calls  churn
# 1995                       2    NaN
# 1996                       1    0.0
# 1997                       0    0.0
# 1998                       3    0.0
# 1999                       1    1.0

# %%
data.describe()
# Out:
#               age  no_of_days_subscribed  weekly_mins_watched  \
# count  2000.00000            2000.000000          2000.000000
# mean     38.69050              99.750000           270.178425
# std      10.20641              39.755386            80.551627
# min      18.00000               1.000000             0.000000
# 25%      32.00000              73.000000           218.212500
# 50%      37.00000              99.000000           269.925000
# 75%      44.00000             127.000000           324.675000
# max      82.00000             243.000000           526.200000
#
#        minimum_daily_mins  maximum_daily_mins  weekly_max_night_mins  \
# count         2000.000000         2000.000000            2000.000000
# mean            10.198700           30.620780             100.415500
# std              2.785519            9.129165              19.529454
# min              0.000000            0.000000              42.000000
# 25%              8.400000           24.735000              87.000000
# 50%             10.200000           30.590000             101.000000
# 75%             12.000000           36.797500             114.000000
# max             20.000000           59.640000             175.000000
#
#        videos_watched  maximum_days_inactive  customer_support_calls  \
# count     2000.000000            1972.000000             2000.000000
# mean         4.482500               3.250507                1.547000
# std          2.487728               0.809084                1.315164
# min          0.000000               0.000000                0.000000
# 25%          3.000000               3.000000                1.000000
# 50%          4.000000               3.000000                1.000000
# 75%          6.000000               4.000000                2.000000
# max         19.000000               6.000000                9.000000
#
#              churn
# count  1965.000000
# mean      0.133333
# std       0.340021
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       1.000000

# %% [markdown]
# ## Droping Null Values

# %%
#checking for null values
data.isna().sum()
# Out:
# gender                    24
# age                        0
# no_of_days_subscribed      0
# multi_screen               0
# mail_subscribed            0
# weekly_mins_watched        0
# minimum_daily_mins         0
# maximum_daily_mins         0
# weekly_max_night_mins      0
# videos_watched             0
# maximum_days_inactive     28
# customer_support_calls     0
# churn                     35
# dtype: int64

# %%
#shape of the data
data.shape
# Out:
# (2000, 13)

# %%
#dropping null values
data = data.dropna(axis=0)

# %%
#shape of the data after dropping null values
data.shape
# Out:
# (1918, 13)

# %% [markdown]
# ## Categorical Variables

# %%
#unique values in gender column
data["gender"].unique()
# Out:
# <StringArray>
# ['Female', 'Male']
# Length: 2, dtype: str

# %%
print(data["multi_screen"].unique())
print(data["mail_subscribed"].unique())
# Out:
# <StringArray>
# ['no', 'yes']
# Length: 2, dtype: str
# <StringArray>
# ['no', 'yes']
# Length: 2, dtype: str

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
#label encoding categorical features
data['gender'] = le.fit_transform(data["gender"])
data['multi_screen']=le.fit_transform(data['multi_screen'])
data['mail_subscribed']=le.fit_transform(data['mail_subscribed'])

# %%
data.head()
# Out:
#    gender  age  no_of_days_subscribed  multi_screen  mail_subscribed  \
# 0       0   36                     62             0                0
# 1       0   39                    149             0                0
# 2       0   65                    126             0                0
# 3       0   24                    131             0                1
# 4       0   40                    191             0                0
#
#    weekly_mins_watched  minimum_daily_mins  maximum_daily_mins  \
# 0               148.35                12.2               16.81
# 1               294.45                 7.7               33.37
# 2                87.30                11.9                9.89
# 3               321.30                 9.5               36.41
# 4               243.00                10.9               27.54
#
#    weekly_max_night_mins  videos_watched  maximum_days_inactive  \
# 0                     82               1                    4.0
# 1                     87               3                    3.0
# 2                     91               1                    4.0
# 3                    102               4                    3.0
# 4                     83               7                    3.0
#
#    customer_support_calls  churn
# 0                       1    0.0
# 1                       2    0.0
# 2                       5    1.0
# 3                       3    0.0
# 4                       1    0.0

# %%
churn_counts = data.groupby("churn").size()
print(churn_counts)
# Out:
# churn
# 0.0    1665
# 1.0     253
# dtype: int64

# %% [markdown]
# ## Numerical

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
#dropping categorical columns and keeping numeircal columns only
data_num = data.drop(["gender", "multi_screen", "mail_subscribed"], axis=1)

# %%
cols = data_num.columns 
data_num = scaler.fit_transform(data_num)

# %%
#list of numerical columns only
cols = list(cols)

# %%
data[cols] = data_num

# %%
data.head()
# Out:
#    gender       age  no_of_days_subscribed  multi_screen  mail_subscribed  \
# 0       0  0.281250               0.252066             0                0
# 1       0  0.328125               0.611570             0                0
# 2       0  0.734375               0.516529             0                0
# 3       0  0.093750               0.537190             0                1
# 4       0  0.343750               0.785124             0                0
#
#    weekly_mins_watched  minimum_daily_mins  maximum_daily_mins  \
# 0             0.281927               0.610            0.281858
# 1             0.559578               0.385            0.559524
# 2             0.165906               0.595            0.165828
# 3             0.610604               0.475            0.610496
# 4             0.461802               0.545            0.461771
#
#    weekly_max_night_mins  videos_watched  maximum_days_inactive  \
# 0               0.300752        0.052632               0.666667
# 1               0.338346        0.157895               0.500000
# 2               0.368421        0.052632               0.666667
# 3               0.451128        0.210526               0.500000
# 4               0.308271        0.368421               0.500000
#
#    customer_support_calls  churn
# 0                0.111111    0.0
# 1                0.222222    0.0
# 2                0.555556    1.0
# 3                0.333333    0.0
# 4                0.111111    0.0

# %%
#defining dependent and indenpendent variables
X = data.drop("churn", axis=1)
Y = data["churn"].astype(int)

# %%
# split a dataset into train and test sets
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X.values, Y, test_size=0.2, random_state=42)

# %% [markdown]
# ## Sequential Neural Network

# %%
#shape of the training data
X.shape
# Out:
# (1918, 12)

# %%
#Hyperparameters for our network
input_size= X.shape[1]
hidden_sizes = [128, 64]
output_size = 2

# %%
import torch
from torch import nn
# Build a feed-forward network
model = nn.Sequential(nn.Linear(input_size, hidden_sizes[0]),
                      nn.ReLU(),
                      nn.Linear(hidden_sizes[0], hidden_sizes[1]),
                      nn.ReLU(),
                      nn.Linear(hidden_sizes[1], output_size),
                      nn.Softmax(dim=1))
print(model)
# Out:
# Sequential(
#   (0): Linear(in_features=12, out_features=128, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=128, out_features=64, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=64, out_features=2, bias=True)
#   (5): Softmax(dim=1)
# )

# %%
from collections import OrderedDict
model_dict = nn.Sequential(OrderedDict([
                      ('fc1', nn.Linear(input_size, hidden_sizes[0])),
                      ('relu1', nn.ReLU()),
                      ('fc2', nn.Linear(hidden_sizes[0], hidden_sizes[1])),
                      ('relu2', nn.ReLU()),
                      ('output', nn.Linear(hidden_sizes[1], output_size)),
                      ('softmax', nn.Softmax(dim=1))]))

# %%
 # Define the loss
criterion = nn.NLLLoss()

# %%
from torch import optim
# Optimizers require the parameters to optimize and a learning rate
optimizer = optim.SGD(model.parameters(), lr=0.01)

# %%
if 'size' in globals(): del size

# %%
import torch.utils.data as Data
X_train, y_train = torch.as_tensor(X_train, dtype=torch.float32), torch.as_tensor(y_train.values if hasattr(y_train, 'values') else y_train, dtype=torch.float32)
BATCH_SIZE = 64


torch_dataset = Data.TensorDataset(X_train, y_train)

loader = Data.DataLoader(
    dataset=torch_dataset, 
    batch_size=BATCH_SIZE, 
    shuffle=True, 
    num_workers=2
)
# Out:
# /tmp/ipykernel_2196/234004.py:2: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at /__w/pytorch/pytorch/torch/csrc/utils/tensor_numpy.cpp:213.)
#   X_train, y_train = torch.as_tensor(X_train, dtype=torch.float32), torch.as_tensor(y_train.values if hasattr(y_train, 'values') else y_train, dtype=torch.float32)

# %% [markdown]
# ## Training the model

# %%
import torch
from torch.autograd import Variable

epochs = 100
for e in range(epochs):
    running_loss = 0
    for step, (batch_x, batch_y) in enumerate(loader):

        b_x = Variable(batch_x)
        b_y = Variable(batch_y.type(torch.LongTensor))
        
        # Training pass
        optimizer.zero_grad()
        
        output = model(b_x)
        loss = criterion(output, b_y)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
        
    else:
        print(f"Training loss: {running_loss/len(X_train)}")
# Out:
# Training loss: -0.008516425648133479
# Training loss: -0.00911803269634968
# Training loss: -0.009734218792001459
# Training loss: -0.01035093798786596
# Training loss: -0.010939522858859662
# Training loss: -0.011470416028931679
# Training loss: -0.011912785149926157
# Training loss: -0.012266682327337651
# Training loss: -0.012537399668737062
# Training loss: -0.012743265990949828
# Training loss: -0.012900639233098036
# Training loss: -0.013019629026795926
# Training loss: -0.01311141975233732
# Training loss: -0.013183995556800275
# Training loss: -0.013242560617305154
# Training loss: -0.013286880750544223
# Training loss: -0.013324678216173254
# Training loss: -0.013355828947940115
# Training loss: -0.013382536685762069
# Training loss: -0.013405546837400115
# Training loss: -0.013423395009208689
# Training loss: -0.013439907438596504
# Training loss: -0.013453269253498261
# Training loss: -0.01346615388154051
# Training loss: -0.01347787633557674
# Training loss: -0.0134854574713278
# Training loss: -0.01349457725396834
# Training loss: -0.013499560886131893
# Training loss: -0.01350956413083779
# Training loss: -0.013514408543025965
# Training loss: -0.013519943265591637
# Training loss: -0.013526289256330886
# Training loss: -0.013528608941658846
# Training loss: -0.01353312634427047
# Training loss: -0.01353699944165415
# Training loss: -0.013543134484794647
# Training loss: -0.013543494327438236
# Training loss: -0.013546203191463765
# Training loss: -0.01354804666132473
# Training loss: -0.01355423629672462
# Training loss: -0.013556355642060102
# Training loss: -0.013557665817429843
# Training loss: -0.013559463204429856
# Training loss: -0.013563077173145996
# Training loss: -0.013565280485650552
# Training loss: -0.01356671701975876
# Training loss: -0.013567401579492561
# Training loss: -0.01356961118662062
# Training loss: -0.013572392982796243
# Training loss: -0.01357280768968913
# Training loss: -0.013573156419602335
# Training loss: -0.013574063272799477
# Training loss: -0.013575583074674146
# Training loss: -0.013576392283495588
# Training loss: -0.01357681211934096
# Training loss: -0.01357881349876931
# Training loss: -0.013580770310709032
# Training loss: -0.013579733368626163
# Training loss: -0.013580953010213422
# Training loss: -0.013583115096819602
# Training loss: -0.013583920769772287
# Training loss: -0.013583717127045255
# Training loss: -0.013583472219564147
# Training loss: -0.013585171185074449
# Training loss: -0.013586512328437597
# Training loss: -0.0135855347578653
# Training loss: -0.013588462301774006
# Training loss: -0.013587756993096065
# Training loss: -0.013588668081564574
# Training loss: -0.01358825170387656
# Training loss: -0.013590431197836626
# Training loss: -0.01359062640887662
# Training loss: -0.01358981910398451
# Training loss: -0.013591288704293958
# Training loss: -0.013592080505761515
# Training loss: -0.013591878222984006
# Training loss: -0.013592653161077486
# Training loss: -0.013593074123738176
# Training loss: -0.013594140324163624
# Training loss: -0.01359388407081793
# Training loss: -0.01359394460799952
# Training loss: -0.013594313542877058
# Training loss: -0.01359565620161253
# Training loss: -0.013596331397122479
# Training loss: -0.013595364978136263
# Training loss: -0.013595366959776997
# Training loss: -0.013596663846497119
# Training loss: -0.01359534205327289
# Training loss: -0.01359826559504443
# Training loss: -0.013596597597527535
# Training loss: -0.013596222212603691
# Training loss: -0.013597154438573348
# Training loss: -0.013599063263722785
# Training loss: -0.013599327715621312
# Training loss: -0.013599257658793065
# Training loss: -0.013598849518513586
# Training loss: -0.013598765085076105
# Training loss: -0.013599982356465624
# Training loss: -0.013600535855921182
# Training loss: -0.013599128541299852

# %%
#testing with test data
import numpy as np
from torch import Tensor


X_test = Tensor(X_test)
y_test = Tensor(np.array(y_test))
z = model(X_test)

# %%
z
# Out:
# tensor([[9.9625e-01, 3.7467e-03],
#         [9.9800e-01, 1.9955e-03],
#         [9.9858e-01, 1.4192e-03],
#         [9.9798e-01, 2.0214e-03],
#         [9.9908e-01, 9.2431e-04],
#         [9.9951e-01, 4.9261e-04],
#         [9.9851e-01, 1.4880e-03],
#         [9.9968e-01, 3.2043e-04],
#         [9.9791e-01, 2.0887e-03],
#         [9.9875e-01, 1.2547e-03],
#         [9.9777e-01, 2.2335e-03],
#         [9.9880e-01, 1.1968e-03],
#         [9.9909e-01, 9.1143e-04],
#         [9.9842e-01, 1.5770e-03],
#         [9.9813e-01, 1.8724e-03],
#         [9.9880e-01, 1.1998e-03],
#         [9.9824e-01, 1.7618e-03],
#         [9.9964e-01, 3.6027e-04],
#         [9.9863e-01, 1.3665e-03],
#         [9.9932e-01, 6.7955e-04],
#         [9.9965e-01, 3.4633e-04],
#         [9.9881e-01, 1.1942e-03],
#         [9.9927e-01, 7.3029e-04],
#         [9.9761e-01, 2.3936e-03],
#         [9.9945e-01, 5.4832e-04],
#         [9.9959e-01, 4.1220e-04],
#         [9.9750e-01, 2.5027e-03],
#         [9.9933e-01, 6.6943e-04],
#         [9.9855e-01, 1.4521e-03],
#         [9.9882e-01, 1.1799e-03],
#         [9.9852e-01, 1.4839e-03],
#         [9.9923e-01, 7.7202e-04],
#         [9.9906e-01, 9.3643e-04],
#         [9.9822e-01, 1.7830e-03],
#         [9.9971e-01, 2.8939e-04],
#         [9.9950e-01, 5.0404e-04],
#         [9.9816e-01, 1.8448e-03],
#         [9.9972e-01, 2.8396e-04],
#         [9.9823e-01, 1.7690e-03],
#         [9.9939e-01, 6.0618e-04],
#         [9.9965e-01, 3.5308e-04],
#         [9.9819e-01, 1.8087e-03],
#         [9.9890e-01, 1.1007e-03],
#         [9.9827e-01, 1.7298e-03],
#         [9.9807e-01, 1.9281e-03],
#         [9.9896e-01, 1.0416e-03],
#         [9.9879e-01, 1.2149e-03],
#         [9.9866e-01, 1.3369e-03],
#         [9.9972e-01, 2.7591e-04],
#         [9.9625e-01, 3.7531e-03],
#         [9.9881e-01, 1.1886e-03],
#         [9.9834e-01, 1.6556e-03],
#         [9.9950e-01, 4.9507e-04],
#         [9.9696e-01, 3.0369e-03],
#         [9.9929e-01, 7.1371e-04],
#         [9.9895e-01, 1.0477e-03],
#         [9.9901e-01, 9.8982e-04],
#         [9.9904e-01, 9.6275e-04],
#         [9.9818e-01, 1.8198e-03],
#         [9.9739e-01, 2.6131e-03],
#         [9.9898e-01, 1.0248e-03],
#         [9.9916e-01, 8.3598e-04],
#         [9.9810e-01, 1.9030e-03],
#         [9.9846e-01, 1.5364e-03],
#         [9.9929e-01, 7.0768e-04],
#         [9.9943e-01, 5.7310e-04],
#         [9.9854e-01, 1.4628e-03],
#         [9.9756e-01, 2.4382e-03],
#         [9.9725e-01, 2.7549e-03],
#         [9.9902e-01, 9.7874e-04],
#         [9.9970e-01, 3.0014e-04],
#         [9.9871e-01, 1.2856e-03],
#         [9.9855e-01, 1.4481e-03],
#         [9.9937e-01, 6.2726e-04],
#         [9.9863e-01, 1.3725e-03],
#         [9.9835e-01, 1.6485e-03],
#         [9.9867e-01, 1.3265e-03],
#         [9.9727e-01, 2.7303e-03],
#         [9.9890e-01, 1.0961e-03],
#         [9.9864e-01, 1.3597e-03],
#         [9.9858e-01, 1.4248e-03],
#         [9.9757e-01, 2.4338e-03],
#         [9.9757e-01, 2.4325e-03],
#         [9.9953e-01, 4.7183e-04],
#         [9.9925e-01, 7.5303e-04],
#         [9.9811e-01, 1.8943e-03],
#         [9.9749e-01, 2.5111e-03],
#         [9.9747e-01, 2.5275e-03],
#         [9.9827e-01, 1.7279e-03],
#         [9.9969e-01, 3.1242e-04],
#         [9.9862e-01, 1.3823e-03],
#         [9.9951e-01, 4.9234e-04],
#         [9.9936e-01, 6.4345e-04],
#         [9.9702e-01, 2.9837e-03],
#         [9.9551e-01, 4.4858e-03],
#         [9.9873e-01, 1.2667e-03],
#         [9.9854e-01, 1.4632e-03],
#         [9.9882e-01, 1.1779e-03],
#         [9.9971e-01, 2.9498e-04],
#         [9.9695e-01, 3.0546e-03],
#         [9.9872e-01, 1.2841e-03],
#         [9.9879e-01, 1.2116e-03],
#         [9.9902e-01, 9.8416e-04],
#         [9.9892e-01, 1.0844e-03],
#         [9.9966e-01, 3.3956e-04],
#         [9.9918e-01, 8.2394e-04],
#         [9.9945e-01, 5.5410e-04],
#         [9.9796e-01, 2.0404e-03],
#         [9.9934e-01, 6.5930e-04],
#         [9.9781e-01, 2.1909e-03],
#         [9.9890e-01, 1.1012e-03],
#         [9.9884e-01, 1.1598e-03],
#         [9.9965e-01, 3.5332e-04],
#         [9.9875e-01, 1.2490e-03],
#         [9.9914e-01, 8.5955e-04],
#         [9.9854e-01, 1.4642e-03],
#         [9.9928e-01, 7.2190e-04],
#         [9.9941e-01, 5.8649e-04],
#         [9.9790e-01, 2.1012e-03],
#         [9.9811e-01, 1.8885e-03],
#         [9.9751e-01, 2.4948e-03],
#         [9.9444e-01, 5.5605e-03],
#         [9.9826e-01, 1.7414e-03],
#         [9.9953e-01, 4.7217e-04],
#         [9.9851e-01, 1.4940e-03],
#         [9.9922e-01, 7.7670e-04],
#         [9.9854e-01, 1.4648e-03],
#         [9.9861e-01, 1.3865e-03],
#         [9.9710e-01, 2.8972e-03],
#         [9.9851e-01, 1.4897e-03],
#         [9.9746e-01, 2.5440e-03],
#         [9.9873e-01, 1.2744e-03],
#         [9.9851e-01, 1.4868e-03],
#         [9.9938e-01, 6.2185e-04],
#         [9.9872e-01, 1.2779e-03],
#         [9.9833e-01, 1.6680e-03],
#         [9.9830e-01, 1.7024e-03],
#         [9.9848e-01, 1.5222e-03],
#         [9.9973e-01, 2.6575e-04],
#         [9.9846e-01, 1.5407e-03],
#         [9.9838e-01, 1.6192e-03],
#         [9.9945e-01, 5.5467e-04],
#         [9.9888e-01, 1.1156e-03],
#         [9.9890e-01, 1.1017e-03],
#         [9.9879e-01, 1.2062e-03],
#         [9.9899e-01, 1.0099e-03],
#         [9.9936e-01, 6.4026e-04],
#         [9.9721e-01, 2.7871e-03],
#         [9.9884e-01, 1.1612e-03],
#         [9.9889e-01, 1.1120e-03],
#         [9.9922e-01, 7.8154e-04],
#         [9.9920e-01, 7.9965e-04],
#         [9.9817e-01, 1.8324e-03],
#         [9.9758e-01, 2.4194e-03],
#         [9.9750e-01, 2.4992e-03],
#         [9.9818e-01, 1.8164e-03],
#         [9.9889e-01, 1.1139e-03],
#         [9.9616e-01, 3.8423e-03],
#         [9.9914e-01, 8.6174e-04],
#         [9.9902e-01, 9.7701e-04],
#         [9.9866e-01, 1.3353e-03],
#         [9.9977e-01, 2.2962e-04],
#         [9.9917e-01, 8.3242e-04],
#         [9.9863e-01, 1.3683e-03],
#         [9.9884e-01, 1.1646e-03],
#         [9.9891e-01, 1.0887e-03],
#         [9.9855e-01, 1.4493e-03],
#         [9.9878e-01, 1.2199e-03],
#         [9.9783e-01, 2.1696e-03],
#         [9.9940e-01, 6.0242e-04],
#         [9.9947e-01, 5.2871e-04],
#         [9.9911e-01, 8.8956e-04],
#         [9.9846e-01, 1.5433e-03],
#         [9.9904e-01, 9.5506e-04],
#         [9.9935e-01, 6.5035e-04],
#         [9.9843e-01, 1.5651e-03],
#         [9.9907e-01, 9.3454e-04],
#         [9.9832e-01, 1.6828e-03],
#         [9.9878e-01, 1.2156e-03],
#         [9.9938e-01, 6.1934e-04],
#         [9.9818e-01, 1.8239e-03],
#         [9.9927e-01, 7.3480e-04],
#         [9.9964e-01, 3.5854e-04],
#         [9.9949e-01, 5.1254e-04],
#         [9.9881e-01, 1.1891e-03],
#         [9.9959e-01, 4.0610e-04],
#         [9.9839e-01, 1.6102e-03],
#         [9.9807e-01, 1.9327e-03],
#         [9.9956e-01, 4.4135e-04],
#         [9.9920e-01, 7.9522e-04],
#         [9.9780e-01, 2.2039e-03],
#         [9.9954e-01, 4.5505e-04],
#         [9.9873e-01, 1.2696e-03],
#         [9.9941e-01, 5.8543e-04],
#         [9.9777e-01, 2.2262e-03],
#         [9.9915e-01, 8.5158e-04],
#         [9.9869e-01, 1.3050e-03],
#         [9.9966e-01, 3.4474e-04],
#         [9.9888e-01, 1.1227e-03],
#         [9.9885e-01, 1.1544e-03],
#         [9.9861e-01, 1.3947e-03],
#         [9.9957e-01, 4.2814e-04],
#         [9.9860e-01, 1.4015e-03],
#         [9.9853e-01, 1.4726e-03],
#         [9.9965e-01, 3.5443e-04],
#         [9.9895e-01, 1.0476e-03],
#         [9.9815e-01, 1.8534e-03],
#         [9.9929e-01, 7.1281e-04],
#         [9.9836e-01, 1.6354e-03],
#         [9.9936e-01, 6.4351e-04],
#         [9.9929e-01, 7.0745e-04],
#         [9.9976e-01, 2.3536e-04],
#         [9.9934e-01, 6.5635e-04],
#         [9.9962e-01, 3.7507e-04],
#         [9.9923e-01, 7.7263e-04],
#         [9.9835e-01, 1.6501e-03],
#         [9.9871e-01, 1.2882e-03],
#         [9.9810e-01, 1.8978e-03],
#         [9.9813e-01, 1.8727e-03],
#         [9.9965e-01, 3.4943e-04],
#         [9.9876e-01, 1.2391e-03],
#         [9.9932e-01, 6.7831e-04],
#         [9.9921e-01, 7.9360e-04],
#         [9.9907e-01, 9.2945e-04],
#         [9.9823e-01, 1.7658e-03],
#         [9.9962e-01, 3.7967e-04],
#         [9.9822e-01, 1.7803e-03],
#         [9.9961e-01, 3.8860e-04],
#         [9.9912e-01, 8.8205e-04],
#         [9.9949e-01, 5.0825e-04],
#         [9.9853e-01, 1.4682e-03],
#         [9.9868e-01, 1.3234e-03],
#         [9.9907e-01, 9.2899e-04],
#         [9.9704e-01, 2.9601e-03],
#         [9.9923e-01, 7.7112e-04],
#         [9.9903e-01, 9.6676e-04],
#         [9.9817e-01, 1.8292e-03],
#         [9.9920e-01, 7.9811e-04],
#         [9.9936e-01, 6.4263e-04],
#         [9.9923e-01, 7.6805e-04],
#         [9.9923e-01, 7.6740e-04],
#         [9.9838e-01, 1.6223e-03],
#         [9.9939e-01, 6.0799e-04],
#         [9.9902e-01, 9.7770e-04],
#         [9.9939e-01, 6.0842e-04],
#         [9.9883e-01, 1.1659e-03],
#         [9.9890e-01, 1.0972e-03],
#         [9.9697e-01, 3.0318e-03],
#         [9.9686e-01, 3.1375e-03],
#         [9.9896e-01, 1.0443e-03],
#         [9.9812e-01, 1.8820e-03],
#         [9.9824e-01, 1.7575e-03],
#         [9.9938e-01, 6.1644e-04],
#         [9.9896e-01, 1.0439e-03],
#         [9.9962e-01, 3.8023e-04],
#         [9.9910e-01, 9.0081e-04],
#         [9.9705e-01, 2.9548e-03],
#         [9.9861e-01, 1.3927e-03],
#         [9.9964e-01, 3.5801e-04],
#         [9.9927e-01, 7.3357e-04],
#         [9.9755e-01, 2.4548e-03],
#         [9.9871e-01, 1.2880e-03],
#         [9.9829e-01, 1.7072e-03],
#         [9.9887e-01, 1.1308e-03],
#         [9.9947e-01, 5.3126e-04],
#         [9.9752e-01, 2.4801e-03],
#         [9.9759e-01, 2.4118e-03],
#         [9.9902e-01, 9.8261e-04],
#         [9.9830e-01, 1.6962e-03],
#         [9.9925e-01, 7.5134e-04],
#         [9.9769e-01, 2.3114e-03],
#         [9.9664e-01, 3.3633e-03],
#         [9.9905e-01, 9.4584e-04],
#         [9.9891e-01, 1.0928e-03],
#         [9.9974e-01, 2.5798e-04],
#         [9.9928e-01, 7.1583e-04],
#         [9.9784e-01, 2.1625e-03],
#         [9.9933e-01, 6.7084e-04],
#         [9.9624e-01, 3.7613e-03],
#         [9.9873e-01, 1.2661e-03],
#         [9.9943e-01, 5.6615e-04],
#         [9.9923e-01, 7.6591e-04],
#         [9.9720e-01, 2.8013e-03],
#         [9.9834e-01, 1.6554e-03],
#         [9.9859e-01, 1.4117e-03],
#         [9.9935e-01, 6.4508e-04],
#         [9.9836e-01, 1.6423e-03],
#         [9.9972e-01, 2.7906e-04],
#         [9.9797e-01, 2.0347e-03],
#         [9.9899e-01, 1.0146e-03],
#         [9.9855e-01, 1.4492e-03],
#         [9.9892e-01, 1.0836e-03],
#         [9.9893e-01, 1.0713e-03],
#         [9.9904e-01, 9.5630e-04],
#         [9.9863e-01, 1.3726e-03],
#         [9.9963e-01, 3.6675e-04],
#         [9.9889e-01, 1.1138e-03],
#         [9.9804e-01, 1.9634e-03],
#         [9.9958e-01, 4.1857e-04],
#         [9.9911e-01, 8.8704e-04],
#         [9.9872e-01, 1.2776e-03],
#         [9.9930e-01, 6.9817e-04],
#         [9.9733e-01, 2.6666e-03],
#         [9.9950e-01, 5.0440e-04],
#         [9.9934e-01, 6.5569e-04],
#         [9.9695e-01, 3.0500e-03],
#         [9.9929e-01, 7.0708e-04],
#         [9.9972e-01, 2.7889e-04],
#         [9.9723e-01, 2.7699e-03],
#         [9.9962e-01, 3.7660e-04],
#         [9.9936e-01, 6.3670e-04],
#         [9.9841e-01, 1.5916e-03],
#         [9.9899e-01, 1.0063e-03],
#         [9.9953e-01, 4.7241e-04],
#         [9.9925e-01, 7.5464e-04],
#         [9.9962e-01, 3.8131e-04],
#         [9.9978e-01, 2.1677e-04],
#         [9.9900e-01, 1.0004e-03],
#         [9.9876e-01, 1.2426e-03],
#         [9.9875e-01, 1.2519e-03],
#         [9.9841e-01, 1.5894e-03],
#         [9.9815e-01, 1.8538e-03],
#         [9.9852e-01, 1.4792e-03],
#         [9.9882e-01, 1.1838e-03],
#         [9.9881e-01, 1.1857e-03],
#         [9.9864e-01, 1.3629e-03],
#         [9.9854e-01, 1.4603e-03],
#         [9.9677e-01, 3.2293e-03],
#         [9.9828e-01, 1.7183e-03],
#         [9.9953e-01, 4.6820e-04],
#         [9.9891e-01, 1.0924e-03],
#         [9.9799e-01, 2.0105e-03],
#         [9.9861e-01, 1.3935e-03],
#         [9.9956e-01, 4.4490e-04],
#         [9.9936e-01, 6.4146e-04],
#         [9.9914e-01, 8.6386e-04],
#         [9.9925e-01, 7.5163e-04],
#         [9.9861e-01, 1.3936e-03],
#         [9.9880e-01, 1.1973e-03],
#         [9.9928e-01, 7.2249e-04],
#         [9.9887e-01, 1.1280e-03],
#         [9.9912e-01, 8.7510e-04],
#         [9.9867e-01, 1.3339e-03],
#         [9.9809e-01, 1.9140e-03],
#         [9.9853e-01, 1.4664e-03],
#         [9.9977e-01, 2.3449e-04],
#         [9.9891e-01, 1.0851e-03],
#         [9.9927e-01, 7.2584e-04],
#         [9.9842e-01, 1.5841e-03],
#         [9.9804e-01, 1.9562e-03],
#         [9.9864e-01, 1.3643e-03],
#         [9.9959e-01, 4.0940e-04],
#         [9.9930e-01, 7.0464e-04],
#         [9.9899e-01, 1.0100e-03],
#         [9.9616e-01, 3.8410e-03],
#         [9.9913e-01, 8.6578e-04],
#         [9.9902e-01, 9.7569e-04],
#         [9.9960e-01, 4.0338e-04],
#         [9.9866e-01, 1.3422e-03],
#         [9.9912e-01, 8.8055e-04],
#         [9.9825e-01, 1.7491e-03],
#         [9.9911e-01, 8.8793e-04],
#         [9.9927e-01, 7.2899e-04],
#         [9.9911e-01, 8.9270e-04],
#         [9.9736e-01, 2.6386e-03],
#         [9.9944e-01, 5.6482e-04],
#         [9.9918e-01, 8.2328e-04],
#         [9.9810e-01, 1.8958e-03],
#         [9.9928e-01, 7.1789e-04],
#         [9.9875e-01, 1.2497e-03],
#         [9.9899e-01, 1.0148e-03],
#         [9.9937e-01, 6.2802e-04],
#         [9.9887e-01, 1.1303e-03],
#         [9.9828e-01, 1.7243e-03],
#         [9.9795e-01, 2.0541e-03],
#         [9.9897e-01, 1.0295e-03],
#         [9.9816e-01, 1.8357e-03],
#         [9.9963e-01, 3.6543e-04],
#         [9.9800e-01, 1.9959e-03],
#         [9.9928e-01, 7.2375e-04],
#         [9.9732e-01, 2.6760e-03],
#         [9.9890e-01, 1.1006e-03],
#         [9.9922e-01, 7.8477e-04],
#         [9.9955e-01, 4.5136e-04]], grad_fn=<SoftmaxBackward0>)
